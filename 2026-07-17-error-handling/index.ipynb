# %% [markdown]
# 2026-07-17 | Will Graham | Mose Gordiano | Stephen Thompson
#
# # DeepSKA - Exceptions and Error Handling
#
# In these notebooks, we'll do something akin to a crash course in error handling.
# Note that we'll be using examples in Python; so we'll typically be using language that reflects Python conventions - most prominently the phrase "`raise` an `Exception`" which is how, in Python, one has an error be thrown.
# But the principles that we're covering are applicable to all other programming languages too.
#
# ## [The Basics](./basics.ipynb)
#
# We'll start by covering the fundamentals of error handling and the core principles and things to bear in mind when considering it.
#
# **Note**: The software carpentry course on Python also contains [a quick introduction to errors and exceptions](https://swcarpentry.github.io/python-novice-inflammation/09-errors.html), that you might want to check out too: <https://swcarpentry.github.io/python-novice-inflammation/09-errors.html>.
#
# - Why use exceptions?
# - Stacktraces and `raise`
# - Informative exceptions
#   - Exception types
#   - Exception messages
#
# ## [General Principles](./principles.ipynb)
#
# Then we'll move onto some "guiding principles" that we can apply, once we understand the foundations.
#
# - "How easy is it for a user to get this wrong?"
# - "How complicated / niche / fundamental is the problem?"
# - "Does someone else already handle this for me?"
# - If someone wants to break something, they will.
#
# ## [Pitfalls and Conventions](conventions.ipynb)
#
# Finally, we have an outline of some of the common pitfalls and conventions that surround errors and exception handling.
#
# - Exceptions are not control flow
# - Fail-fast
# - Custom exceptions
